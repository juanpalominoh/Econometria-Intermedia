# %% [markdown]
# <a href="https://colab.research.google.com/github/juanpalominoh/Econometria-Intermedia/blob/main/Tema_1_3_Heterocedasticidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tema 1.3 - Heterocedasticidad**

# %%
library(readxl)

# %%
base <- read_excel("base.xlsx")
base
# Out:
#      conglome vivienda hogar dpto urbano costa sierra lima mieperho galimentos
# 1    007488   004      11    15   1      0     0      1    4         9137.330
# 2    007488   043      11    15   1      0     0      1    4         3913.549
# 3    007488   056      11    15   1      0     0      1    4        13400.405
# 4    007488   084      11    15   1      0     0      1    3         9165.153
# 5    007488   108      11    15   1      0     0      1    5         4488.108
# 6    007530   004      11    15   1      0     0      1    1         5424.277
# 7    007530   044      11    15   1      0     0      1    2         2303.446
# 8    007530   065      11    15   1      0     0      1    2         2126.189
# 9    007530   082      11    15   1      0     0      1    4        10938.024
# 10   007530   099      11    15   1      0     0      1    2        13141.726
# 11   007530   153      11    15   1      0     0      1    3         6861.835
# 12   007533   037      11    15   1      0     0      1    3         5766.040
# 13   007533   060      11    15   1      0     0      1    2        10597.300
# 14   007533   083      11    15   1      0     0      1    1         3202.724
# 15   007533   107      11    15   1      0     0      1    3         7457.765
# 16   007533   132      11    15   1      0     0      1    6        10598.890
# 17   007533   174      11    15   1      0     0      1    6        11902.675
# 18   007534   005      11    15   1      0     0      1    3         8753.260
# 19   007534   038      11    15   1      0     0      1    1         3833.727
# 20   007534   076      11    15   1      0     0      1    4        13484.722
# 21   007534   092      11    15   1      0     0      1    1         3346.323
# 22   007534   145      11    15   1      0     0      1    3         4899.084
# 23   007535   032      11    15   1      0     0      1    8        17338.154
# 24   007535   050      11    15   1      0     0      1    4        31622.232
# 25   007535   068      11    15   1      0     0      1    5         8038.393
# 26   007535   086      11    15   1      0     0      1    1         7472.582
# 27   007535   103      11    15   1      0     0      1    3         5801.651
# 28   007535   121      11    15   1      0     0      1    1         1847.958
# 29   007536   005      11    15   1      0     0      1    2         9725.034
# 30   007536   036      11    15   1      0     0      1    3         4461.643
# ⋮    ⋮        ⋮        ⋮     ⋮    ⋮      ⋮     ⋮      ⋮    ⋮        ⋮
# 4485 010261   013      11    15   1      1     0      0    2         2635.469
# 4486 010261   028      11    15   1      1     0      0    5         7734.523
# 4487 010261   056      11    15   1      1     0      0    2         1328.534
# 4488 010261   069      11    15   1      1     0      0    2         1698.561
# 4489 010261   083      11    15   1      1     0      0    1         2890.762
# 4490 010261   097      11    15   1      1     0      0    7         8906.088
# 4491 010633   013      11    15   1      1     0      0    6        11540.238
# 4492 010633   028      11    15   1      1     0      0    2         5588.058
# 4493 010633   043      11    15   1      1     0      0    3         7285.054
# 4494 010633   072      11    15   1      1     0      0    4         4033.319
# 4495 010633   086      11    15   1      1     0      0    7        12487.431
# 4496 010633   103      11    15   1      1     0      0    2         4528.272
# 4497 010640   012      11    15   1      1     0      0    5         8891.531
# 4498 010640   042      11    15   1      1     0      0    1         2798.526
# 4499 010640   057      11    15   1      1     0      0    7         2165.078
# 4500 010640   087      11    15   1      1     0      0    3        10040.863
# 4501 010640   103      11    15   1      1     0      0    9        18864.068
# 4502 010640   133      11    15   1      1     0      0    9        16502.330
# 4503 010645   002      11    15   1      1     0      0    2         2674.507
# 4504 010645   016      11    15   1      1     0      0    5        16282.208
# 4505 010645   028      11    15   1      1     0      0    4         8933.906
# 4506 010645   055      11    15   1      1     0      0    5         7711.734
# 4507 010645   066      11    15   1      1     0      0    4         9630.869
# 4508 010645   080      11    15   1      1     0      0    3         7175.546
# 4509 010656   007      11    15   1      1     0      0    4         5298.729
# 4510 010656   023      11    15   1      1     0      0    1         3273.853
# 4511 010656   039      11    15   1      1     0      0    3         8323.914
# 4512 010656   072      11    15   1      1     0      0    4         5438.094
# 4513 010656   086      11    15   1      1     0      0    3         6236.108
# 4514 010656   104      11    15   1      1     0      0    5        16325.022
#      ingresos   ing2        lnalim    lning     lning2
# 1     30310.555   918729728  9.120124 10.319251 106.48695
# 2    120410.586 14498709504  8.272200 11.698663 136.85870
# 3     35705.848  1274907520  9.503040 10.483069 109.89474
# 4    192277.500 36970635264  9.123164 12.166695 148.02846
# 5     36903.539  1361871232  8.409186 10.516063 110.58758
# 6     26586.104   706820928  8.598639 10.188144 103.79827
# 7     20876.879   435844064  7.742161  9.946398  98.93083
# 8      3229.922    10432397  7.662086  8.080214  65.28985
# 9     11758.236   138256128  9.300000  9.372310  87.84019
# 10    33294.801  1108543744  9.483547 10.413157 108.43383
# 11    24826.764   616368192  8.833730 10.119678 102.40788
# 12    22488.838   505747840  8.659740 10.020775 100.41593
# 13    32026.162  1025675072  9.268354 10.374309 107.62628
# 14    11744.084   137923504  8.071757  9.371105  87.81761
# 15    61827.098  3822589952  8.917011 11.032097 121.70716
# 16    32601.398  1062851200  9.268504 10.392111 107.99596
# 17    36045.066  1299246848  9.384519 10.492525 110.09309
# 18    39399.328  1552307072  9.077182 10.581504 111.96822
# 19    41409.965  1714785152  8.251593 10.631277 113.02406
# 20    66053.625  4363081216  9.509313 11.098222 123.17052
# 21    16174.013   261598688  8.115618  9.691161  93.91860
# 22    46037.621  2119462528  8.496803 10.737214 115.28777
# 23    30285.912   917236480  9.760665 10.318438 106.47015
# 24    56692.145  3213999360 10.361616 10.945391 119.80157
# 25    41099.031  1689130368  8.991984 10.623740 112.86385
# 26    52598.746  2766628096  8.918996 10.870447 118.16662
# 27    14658.628   214875376  8.665898  9.592784  92.02151
# 28    12819.260   164333424  7.521836  9.458704  89.46708
# 29    37318.562  1392675072  9.182459 10.527246 110.82292
# 30    28914.818   836066752  8.403273 10.272109 105.51623
# ⋮    ⋮          ⋮           ⋮         ⋮         ⋮
# 4485  15373.416   236341920 7.876816   9.640395  92.93722
# 4486  15299.173   234064688 8.953449   9.635554  92.84391
# 4487  12063.825   145535872 7.191831   9.397966  88.32177
# 4488  19581.230   383424576 7.437537   9.882327  97.66039
# 4489  25930.002   672364992 7.969275  10.163156 103.28973
# 4490 134651.859 18131124224 9.094490  11.810448 139.48668
# 4491  40630.043  1650800384 9.353595  10.612263 112.62012
# 4492   7515.201    56478240 8.628387   8.924683  79.64996
# 4493  35038.812  1227718400 8.893580  10.464211 109.49973
# 4494  12531.222   157031520 8.302345   9.435979  89.03770
# 4495  43497.336  1892018176 9.432478  10.680455 114.07212
# 4496  10663.462   113709416 8.418096   9.274578  86.01780
# 4497  23162.000   536478240 9.092854  10.050268 101.00789
# 4498  11947.349   142739136 7.936848   9.388265  88.13951
# 4499  66609.453  4436819456 7.680212  11.106602 123.35660
# 4500  29337.617   860695808 9.214418  10.286626 105.81467
# 4501  67723.141  4586423808 9.845015  11.123183 123.72520
# 4502 135806.734 18443468800 9.711257  11.818988 139.68848
# 4503   8887.210    78982504 7.891521   9.092368  82.67116
# 4504  58240.797  3391990528 9.697828  10.972342 120.39228
# 4505  22115.568   489098368 9.097609  10.004037 100.08076
# 4506  77681.734  6034451968 8.950499  11.260375 126.79604
# 4507  43276.988  1872897664 9.172729  10.675376 113.96365
# 4508  27332.418   747061056 8.878434  10.215829 104.36316
# 4509  41731.730  1741537280 8.575222  10.639017 113.18868
# 4510  12742.658   162375344 8.093723   9.452710  89.35373
# 4511  31508.701   992798272 9.026888  10.358019 107.28855
# 4512  32220.746  1038176448 8.601184  10.380365 107.75198
# 4513  40291.625  1623415040 8.738111  10.603899 112.44267
# 4514  60818.004  3698829568 9.700455  11.015641 121.34435

# %%
names(base)
# Out:
#  [1] "conglome"   "vivienda"   "hogar"      "dpto"       "urbano"
#  [6] "costa"      "sierra"     "lima"       "mieperho"   "galimentos"
# [11] "ingresos"   "ing2"       "lnalim"     "lning"      "lning2"

# %%
options(prompt="R> ", digits=4, scipen=999)

# %% [markdown]
# # 1. Modelo MCO

# %%
formula <- lnalim ~ lning + mieperho + urbano + costa + sierra

# %%
ols <- lm(formula, data = base)
summary(ols)
# Out:
# Call:
# lm(formula = formula, data = base)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.381 -0.222  0.139  0.432  1.984
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  3.99550    0.20114   19.86 <0.0000000000000002 ***
# lning        0.37223    0.01925   19.33 <0.0000000000000002 ***
# mieperho     0.17711    0.00748   23.68 <0.0000000000000002 ***
# urbano       0.16220    0.05502    2.95              0.0032 **
# costa       -0.01235    0.03348   -0.37              0.7122
# sierra      -0.16440    0.06574   -2.50              0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.871 on 4508 degrees of freedom
# Multiple R-squared:  0.282,	Adjusted R-squared:  0.281
# F-statistic:  354 on 5 and 4508 DF,  p-value: <0.0000000000000002

# %% [markdown]
# # 2. Pruebas de Heterocedasticidad

# %%
install.packages("stargazer")
library("stargazer")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %% [markdown]
# ## 2.1. Test White (1era Forma)

# %%
# a. Capturo los residuos
resids <-ols$residuals
data_frame_white<-as.data.frame(cbind(base, resids))

# %%
# b. Regresion auxiliar
formula2 <- I(resids^2) ~ lning + mieperho + urbano + costa + sierra +
                  I(lning^2) + (lning*mieperho) + (lning*urbano) + (lning*costa) + (lning*sierra) +
                  I(mieperho^2) + (mieperho*urbano)+(mieperho*costa)+(mieperho*sierra)+
                  (urbano*costa)
  
regresion_auxiliar <- lm(formula2, data = data_frame_white)
sumario<- summary(regresion_auxiliar)
sumario
# Out:
# Call:
# lm(formula = formula2, data = data_frame_white)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -6.77  -0.76  -0.30  -0.01  87.97
#
# Coefficients:
#                  Estimate Std. Error t value  Pr(>|t|)
# (Intercept)      54.92440   11.97631    4.59 0.0000046 ***
# lning           -10.12184    2.20687   -4.59 0.0000046 ***
# mieperho         -0.51260    0.71202   -0.72    0.4716
# urbano           10.55387    4.78113    2.21    0.0273 *
# costa            -6.70059    3.29756   -2.03    0.0422 *
# sierra          -17.30859    5.76348   -3.00    0.0027 **
# I(lning^2)        0.50977    0.10616    4.80 0.0000016 ***
# I(mieperho^2)     0.04113    0.01296    3.17    0.0015 **
# lning:mieperho   -0.02314    0.06991   -0.33    0.7406
# lning:urbano     -1.31952    0.49961   -2.64    0.0083 **
# lning:costa       0.45208    0.33159    1.36    0.1728
# lning:sierra      1.67223    0.59787    2.80    0.0052 **
# mieperho:urbano   0.31760    0.19152    1.66    0.0973 .
# mieperho:costa   -0.00946    0.11255   -0.08    0.9330
# mieperho:sierra  -0.18022    0.22529   -0.80    0.4238
# urbano:costa      1.67447    0.75249    2.23    0.0261 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.03 on 4498 degrees of freedom
# Multiple R-squared:  0.0239,	Adjusted R-squared:  0.0207
# F-statistic: 7.35 on 15 and 4498 DF,  p-value: 0.000000000000000243

# %%
# c. Validar la hipótesis nula
n <- nrow(data_frame_white)
R_2<- sumario$r.squared
LM_W<- n*R_2
gl <- 15        # Numero de variables explicativas de la ecuación auxiliar
p_value<- 1- pchisq(q = LM_W, df = gl)
VC<- qchisq(p = 0.95, df = gl)
salida_white<- c(LM_W, VC, p_value)
names(salida_white)<-c("LMw", "Valor critico", "p-value")
stargazer(salida_white, title = "Resultados de la prueba de white", type = "text", digits =0)
# Out:
# Resultados de la prueba de white
# =========================
# LMw Valor critico p-value
# -------------------------
# 108      25          0
# -------------------------

# %% [markdown]
# ## 2.2. Test White (2da forma)

# %%
install.packages("lmtest")
library(lmtest)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘zoo’
#
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
prueba_white <- bptest(ols, 
                      ~ lning + mieperho + urbano + costa + sierra +
                        I(lning^2) + (lning*mieperho) + (lning*urbano) + (lning*costa) + (lning*sierra) +
                        I(mieperho^2) + (mieperho*urbano)+(mieperho*costa)+(mieperho*sierra)+
                        (urbano*costa),
                        data = base)
print(prueba_white)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  ols
# BP = 108, df = 15, p-value = 0.0000000000000004

# %% [markdown]
# ## 2.3. Test Breusch-Pagan/Godfrey

# %%
bpg <- bptest(formula, studentize = F, data=base)
bpg
# Out:
# 	Breusch-Pagan test
#
# data:  formula
# BP = 887, df = 5, p-value <0.0000000000000002

# %% [markdown]
# # 3. Modelo WLS

# %%
ols <- lm(formula, data = base)
summary(ols)
# Out:
# Call:
# lm(formula = formula, data = base)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.381 -0.222  0.139  0.432  1.984
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  3.99550    0.20114   19.86 <0.0000000000000002 ***
# lning        0.37223    0.01925   19.33 <0.0000000000000002 ***
# mieperho     0.17711    0.00748   23.68 <0.0000000000000002 ***
# urbano       0.16220    0.05502    2.95              0.0032 **
# costa       -0.01235    0.03348   -0.37              0.7122
# sierra      -0.16440    0.06574   -2.50              0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.871 on 4508 degrees of freedom
# Multiple R-squared:  0.282,	Adjusted R-squared:  0.281
# F-statistic:  354 on 5 and 4508 DF,  p-value: <0.0000000000000002

# %%
confint(ols, level=0.95)
resids  <- ols$residuals
resids2 <- resids^2
# Out:
#             2.5 %    97.5 %
# (Intercept)  3.60116  4.38983
# lning        0.33449  0.40998
# mieperho     0.16245  0.19177
# urbano       0.05433  0.27006
# costa       -0.07799  0.05329
# sierra      -0.29328 -0.03553

# %%
wls <- lm(formula, data = base, weights=(1/resids2))
summary(wls)
# Out:
# Call:
# lm(formula = formula, data = base, weights = (1/resids2))
#
# Weighted Residuals:
#    Min     1Q Median     3Q    Max
# -1.735 -1.000  0.994  0.999  1.718
#
# Coefficients:
#              Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  4.003303   0.003930  1018.6 <0.0000000000000002 ***
# lning        0.372019   0.000239  1554.8 <0.0000000000000002 ***
# mieperho     0.176950   0.000111  1594.6 <0.0000000000000002 ***
# urbano       0.157640   0.002536    62.2 <0.0000000000000002 ***
# costa       -0.011929   0.000439   -27.2 <0.0000000000000002 ***
# sierra      -0.166501   0.003295   -50.5 <0.0000000000000002 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1 on 4508 degrees of freedom
# Multiple R-squared:  0.999,	Adjusted R-squared:  0.999
# F-statistic: 7.37e+05 on 5 and 4508 DF,  p-value: <0.0000000000000002

# %%
confint(wls, level=0.95)
# Out:
#             2.5 %    97.5 %
# (Intercept)  3.99560  4.01101
# lning        0.37155  0.37249
# mieperho     0.17673  0.17717
# urbano       0.15267  0.16261
# costa       -0.01279 -0.01107
# sierra      -0.17296 -0.16004

# %%
ci_ols <- confint(ols, level=0.95)
ci_wls <- confint(wls, level=0.95)
ci_ols
ci_wls
ci_ols[,2] - ci_ols[,1]
ci_wls[,2] - ci_wls[,1]
# Los intervalos de confianza de WLS son más estrechos o pequeños que los de OLS
# Por lo tanto, de acuerdo a la teoría, FGLS con un modelo corregido
# por heterocedasticidad es más eficiente que OLS
# Out:
#             2.5 %    97.5 %
# (Intercept)  3.60116  4.38983
# lning        0.33449  0.40998
# mieperho     0.16245  0.19177
# urbano       0.05433  0.27006
# costa       -0.07799  0.05329
# sierra      -0.29328 -0.03553
#             2.5 %    97.5 %
# (Intercept)  3.99560  4.01101
# lning        0.37155  0.37249
# mieperho     0.17673  0.17717
# urbano       0.15267  0.16261
# costa       -0.01279 -0.01107
# sierra      -0.17296 -0.16004
# (Intercept)       lning    mieperho      urbano       costa      sierra
#     0.78866     0.07549     0.02932     0.21573     0.13128     0.25775
# (Intercept)       lning    mieperho      urbano       costa      sierra
#   0.0154104   0.0009382   0.0004351   0.0099419   0.0017200   0.0129211

# %% [markdown]
# # 4. Modelo con errores estándar White

# %%
install.packages("sandwich")
library("sandwich")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
coeftest(ols, vcov=vcovHC(ols, "HC1"))
# Out:
# t test of coefficients:
#
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  3.99550    0.26423   15.12 <0.0000000000000002 ***
# lning        0.37223    0.02571   14.48 <0.0000000000000002 ***
# mieperho     0.17711    0.00856   20.70 <0.0000000000000002 ***
# urbano       0.16220    0.05425    2.99              0.0028 **
# costa       -0.01235    0.03267   -0.38              0.7054
# sierra      -0.16440    0.06897   -2.38              0.0172 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
